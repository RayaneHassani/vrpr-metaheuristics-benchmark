# %% [markdown]
# # Plan de livrable
#
# ## 1. Représentation formelle des données du problème A
# - Explication du contexte général TSP
# - Explication du contexte du projet (entreprise que l'on représente)
# - Choix des contraintes parmi la liste proposée
# - Décrire les variables
#
# Ensemble des variables :
# ### Variables
#
# - graphe G avec (V,E)
# - $x_{ijk} \in \{0, 1\}$
# - $c_{ij} \in \mathbb{C}$
# - $u_{ik} \in \mathbb{N}$
#
#
# ## 2. Représentation formelle de l’objectif à optimiser R
# - Décrire la fonction objectif à minimiser ou maximiser.
# - Préciser le sens de l’optimisation et les variables de décision.
# - Donner la formulation mathématique complète de l’objectif.
#
# ### Fonction objectif
#
# $$
# \min \sum_{k \in K} \sum_{(i,j) \in A} c_{ij} \cdot x_{ijk}
# $$
#
# ## 3. Contraintes A
# C1 : Chaque client visité une fois$$\sum_{k \in K} \sum_{j \neq i} x_{ijk} = 1 \quad \forall i \in C$$C2 : Conservation du flot$$\sum_{j} x_{jik} = \sum_{j} x_{ijk} \quad \forall i \in C, \forall k \in K$$C3 : Départ du dépôt$$\sum_{j \in C} x_{0jk} = 1 \quad \forall k \in K$$C4 : Retour au dépôt$$\sum_{i \in C} x_{i0k} = 1 \quad \forall k \in K$$C5 : Arêtes interdites$$x_{ijk} = 0 \quad \forall (i,j) \in F$$
# - Expliquer comment ces contraintes sont intégrées dans le modèle.
#
# ## 4. Complexité théorique R
# - Analyser la complexité du problème à partir de la formulation formelle.
# - Identifier si le problème est NP-complet, NP-difficile, ou appartient à une autre classe.
# - Expliquer les implications en termes de temps de calcul et d’algorithmes approchés ou exacts. méta heuristiques ? ?
#
# ## 5. Références bibliographiques
# - Lister les sources, articles, livres ou documents utilisés.
# - Inclure des références formatées (auteur, année, titre, publication).
# - Ajouter des liens vers les ressources pertinentes si nécessaire.
